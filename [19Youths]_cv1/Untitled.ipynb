# %%
import cv2              #Import the OpenCV Library
import numpy as np      #Import the Numpy library
import sys             #Import the OpenCV Library

img = cv2.imread("C:\testAI\tello_re\new\Datas\face/wanjae.jpg")
cv2.imshow(img)                 #Display that image
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-df860054062d> in <module>
#       4
#       5 img = cv2.imread("C:\testAI\tello_re\new\Datas\face/wanjae.jpg")
# ----> 6 cv2.imshow(img)                 #Display that image
#
# TypeError: imshow() missing required argument 'mat' (pos 2)

# %%
from matplotlib import pyplot as plt
img=cv2.imread("C:/testAI/tello_re/new/Datas/wj.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis()
plt.show()
print(img.shape)
# Out:
# (961, 722, 3)

# %%
dst = cv2.resize(img, dsize=(224, 224), interpolation=cv2.INTER_AREA)

# %%
print(dst.shape)
# Out:
# (224, 224, 3)

# %%
 cv2.imwrite('wj224.jpg', dst)
# Out:
# True
